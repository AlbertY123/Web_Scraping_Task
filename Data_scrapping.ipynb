# %% [markdown]
# # Jupyter Notebook: Web Scraping Books to Scrape

# %% [markdown]
# ## Step 1: Install Required Libraries
# First, ensure you have the necessary libraries installed. Run the following command in the terminal:
#
# `pip install requests beautifulsoup4 pandas`
#
# ## Step 2: Import Libraries
# Import the required Python libraries.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Step 3: Send a Request to the Website
# Send an HTTP request to the website and retrieve the HTML content.

# %%
# Define the URL of the website
url = "http://books.toscrape.com/"

# Send a GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    print("Successfully connected to the website!")
else:
    print("Failed to connect to the website.")
# Out:
# Successfully connected to the website!

# %% [markdown]
# ## Step 4: Parse the HTML Content
# Use BeautifulSoup to parse the HTML content and extract data.

# %%
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, "html.parser")

# Print the title of the webpage to verify parsing
print("Page Title:", soup.title.text)
# Out:
# Page Title:
#     All products | Books to Scrape - Sandbox

# %% [markdown]
# ## Step 5: Inspect the Website Structure
# Before scraping, inspect the website structure using your browser’s Developer Tools (right-click → Inspect). Identify the HTML elements containing the book data (e.g., titles, prices, ratings).
#
# For example:
#
# - Book titles are inside \<h3\> tags.
#
# - Prices are inside \<p class="price_color"\> tags.
#
# - Ratings are inside \<p class="star-rating"\> tags.
#
# ## Step 6: Extract Book Data
# Extract the book titles, prices, and ratings from the webpage.

# %%
# Find all book containers (each book is inside an <article> tag)
books = soup.find_all("article", class_="product_pod")

# Initialize lists to store the data
titles = []
prices = []
ratings = []

# Loop through each book and extract the data
for book in books:
    # Extract the title
    title = book.h3.a["title"]
    titles.append(title)
    
    # Extract the price
    price = book.find("p", class_="price_color").text
    prices.append(price)
    
    # Extract the rating
    rating = book.p["class"][1]  # The second class name indicates the rating (e.g., "Three")
    ratings.append(rating)

# Print the first few entries to verify
print("Titles:", titles[:5])
print("Prices:", prices[:5])
print("Ratings:", ratings[:5])
# Out:
# Titles: ['A Light in the Attic', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History of Humankind']
# Prices: ['Â£51.77', 'Â£53.74', 'Â£50.10', 'Â£47.82', 'Â£54.23']
# Ratings: ['Three', 'One', 'One', 'Four', 'Five']

# %% [markdown]
# ## Step 7: Save the Data to a DataFrame
# Store the extracted data in a Pandas DataFrame for further analysis.

# %%
# Create a DataFrame
data = {
    "Title": titles,
    "Price": prices,
    "Rating": ratings
}

df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                                    Title    Price Rating
# 0                   A Light in the Attic  Â£51.77  Three
# 1                     Tipping the Velvet  Â£53.74    One
# 2                             Soumission  Â£50.10    One
# 3                          Sharp Objects  Â£47.82   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23   Five

# %% [markdown]
# ## Step 8: Save the Data to a CSV File
# Save the scraped data to a CSV file for later use.

# %%
# Save the DataFrame to a CSV file
df.to_csv("books_data.csv", index=False)

print("Data saved to books_data.csv!")
# Out:
# Data saved to books_data.csv!

# %% [markdown]
# # Investigation Tasks
#
# **Task 1**: Scrape Additional Data
# Description: Extend the scraper to collect additional data, such as:
#
# Book descriptions (found on individual book pages).
#
# Book availability (in stock or out of stock).
#
# Hint: Use the links to individual book pages (found in the \<h3\> tags) to scrape additional details.
#
# <span style="color:red">(2 marks)</span>

# %%
print(df)
# Out:
#                                                 Title    Price Rating
# 0                                A Light in the Attic  Â£51.77  Three
# 1                                  Tipping the Velvet  Â£53.74    One
# 2                                          Soumission  Â£50.10    One
# 3                                       Sharp Objects  Â£47.82   Four
# 4               Sapiens: A Brief History of Humankind  Â£54.23   Five
# 5                                     The Requiem Red  Â£22.65    One
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34   Four
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93  Three
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60   Four
# 9                                     The Black Maria  Â£52.15    One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99    Two
# 11                              Shakespeare's Sonnets  Â£20.66   Four
# 12                                        Set Me Free  Â£17.46   Five
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  Â£52.29   Five
# 14                          Rip it Up and Start Again  Â£35.02   Five
# 15  Our Band Could Be Your Life: Scenes from the A...  Â£57.25  Three
# 16                                               Olio  Â£23.88    One
# 17  Mesaerion: The Best Science Fiction Stories 18...  Â£37.59    One
# 18                       Libertarianism for Beginners  Â£51.33    Two
# 19                            It's Only the Himalayas  Â£45.17    Two

# %%
# Your answer goes here
descriptions = []
availability = []
for book in books:
    #Find link
    link = book.find("a")["href"]
    final_link = url + link
    response = requests.get(final_link)
    soup = BeautifulSoup(response.text, "html.parser")
    # Description
    description = soup.find("meta", {"name": "description"})["content"]
    descriptions.append(description)
    # Book availability
    availabe = soup.find("p", class_="instock availability").text.strip()
    availability.append(availabe)
# Put into dataframe
df["Description"] = descriptions
df["Availability"] = availability
print(df)
# Out:
#                                                 Title    Price Rating  \
# 0                                A Light in the Attic  Â£51.77  Three
# 1                                  Tipping the Velvet  Â£53.74    One
# 2                                          Soumission  Â£50.10    One
# 3                                       Sharp Objects  Â£47.82   Four
# 4               Sapiens: A Brief History of Humankind  Â£54.23   Five
# 5                                     The Requiem Red  Â£22.65    One
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34   Four
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93  Three
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60   Four
# 9                                     The Black Maria  Â£52.15    One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99    Two
# 11                              Shakespeare's Sonnets  Â£20.66   Four
# 12                                        Set Me Free  Â£17.46   Five
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  Â£52.29   Five
# 14                          Rip it Up and Start Again  Â£35.02   Five
# 15  Our Band Could Be Your Life: Scenes from the A...  Â£57.25  Three
# 16                                               Olio  Â£23.88    One
# 17  Mesaerion: The Best Science Fiction Stories 18...  Â£37.59    One
# 18                       Libertarianism for Beginners  Â£51.33    Two
# 19                            It's Only the Himalayas  Â£45.17    Two
#
#                                           Description             Availability
# 0   \n    It's hard to imagine a world without A L...  In stock (22 available)
# 1   \n    "Erotic and absorbing...Written with sta...  In stock (20 available)
# 2   \n    Dans une France assez proche de la nÃ´tr...  In stock (20 available)
# 3   \n    WICKED above her hipbone, GIRL across he...  In stock (20 available)
# 4   \n    From a renowned historian comes a ground...  In stock (20 available)
# 5   \n    Patient Twenty-nine.A monster roams the ...  In stock (19 available)
# 6   \n    Drawing on his extensive experience eval...  In stock (19 available)
# 7   \n    "If you have a heart, if you have a soul...  In stock (19 available)
# 8   \n    For readers of Laura Hillenbrand's Seabi...  In stock (19 available)
# 9   \n    Praise for Aracelis Girmay:"[Girmay's] e...  In stock (19 available)
# 10  \n    Since her assault, Miss Annette Chetwynd...  In stock (19 available)
# 11  \n    This book is an important and complete c...  In stock (19 available)
# 12  \n    Aaron Ledbetterâs future had been plan...  In stock (19 available)
# 13  \n    Scott Pilgrim's life is totally sweet. H...  In stock (19 available)
# 14  \n    Punk's raw power rejuvenated rock, but b...  In stock (19 available)
# 15  \n    This is the never-before-told story of t...  In stock (19 available)
# 16  \n    Part fact, part fiction, Tyehimba Jess's...  In stock (19 available)
# 17  \n    Andrew Barger, award-winning author and ...  In stock (19 available)
# 18  \n    Libertarianism isn't about winning elect...  In stock (19 available)
# 19  \n    âWherever you go, whatever you do, jus...  In stock (19 available)

# %% [markdown]
# **Task 2**: Scrape Multiple Pages
# Description: Modify the script to scrape data from all 50 pages of the Books to Scrape website.
#
# Hint: Use a loop to iterate through the pages. The URL for each page follows the pattern: http://books.toscrape.com/catalogue/page-{page_number}.html.
#
# <span style="color:red">(2 marks)</span>

# %%
# Your answer goes here
title = []
price = []
rating = []
descriptions = []
availability = []
for i in range(1, 50):
    response = requests.get(url + "catalogue/page-" + str(i) + ".html")
    soup = BeautifulSoup(response.text, "html.parser")
    books = soup.find_all("article", class_="product_pod")
    for book in books:
        #Find link
        link = book.find("a")["href"]
        final_link = url + "catalogue/" + link
        response = requests.get(final_link)
        soup = BeautifulSoup(response.text, "html.parser")
        # Title
        title.append(soup.find("h1").text)
        # Price
        price.append(soup.find("p", class_="price_color").text)
        # Rating
        rate = book.p["class"][1]  # The second class name indicates the rating (e.g., "Three")
        rating.append(rate)
        # Description
        description = soup.find("meta", {"name": "description"})["content"]
        descriptions.append(description)
        # Book availability
        available = soup.find("p", class_="instock availability").text.strip()
        availability.append(availabe)
print(df)
# Out:
#                                                 Title    Price Rating  \
# 0                                A Light in the Attic  Â£51.77  Three
# 1                                  Tipping the Velvet  Â£53.74    One
# 2                                          Soumission  Â£50.10    One
# 3                                       Sharp Objects  Â£47.82   Four
# 4               Sapiens: A Brief History of Humankind  Â£54.23   Five
# 5                                     The Requiem Red  Â£22.65    One
# 17  \n    Susan, Esther, and Daisy started at univ...
# 18  \n    Susan, Esther, and Daisy started at univ...
# 19  \n    Susan, Esther, and Daisy started at univ...
#
#    \n    A family with an ancient curse...And the girl who will change their lives forever...Tohru Honda was an orphan with no place to go until the mysterious Sohma family offered her a place to call home. Now her ordinary high school life is turned upside down as she's introduced to the Sohma's world of magical curses and family secrets.\n  \
# 0   \n    A family with an ancient curse...And the...
# 1   \n    A family with an ancient curse...And the...
# 2   \n    A family with an ancient curse...And the...
# 3   \n    A family with an ancient curse...And the...
# 4   \n    A family with an ancient curse...And the...
# 5   \n    A family with an ancient curse...And the...
# 6   \n    A family with an ancient curse...And the...
# 7   \n    A family with an ancient curse...And the...
# 8   \n    A family with an ancient curse...And the...
# 9   \n    A family with an ancient curse...And the...
# 10  \n    A family with an ancient curse...And the...
# 11  \n    A family with an ancient curse...And the...
# 12  \n    A family with an ancient curse...And the...
# 13  \n    A family with an ancient curse...And the...
# 14  \n    A family with an ancient curse...And the...
# 15  \n    A family with an ancient curse...And the...
# 16  \n    A family with an ancient curse...And the...
# 17  \n    A family with an ancient curse...And the...
# 18  \n    A family with an ancient curse...And the...
# 19  \n    A family with an ancient curse...And the...
#
#     In stock (19 available)
# 0   In stock (19 available)
# 1   In stock (19 available)
# 2   In stock (19 available)
# 3   In stock (19 available)
# 4   In stock (19 available)
# 5   In stock (19 available)
# 6   In stock (19 available)
# 7   In stock (19 available)
# 8   In stock (19 available)
# 9   In stock (19 available)
# 10  In stock (19 available)
# 11  In stock (19 available)
# 12  In stock (19 available)
# 13  In stock (19 available)
# 14  In stock (19 available)
# 15  In stock (19 available)
# 16  In stock (19 available)
# 17  In stock (19 available)
# 18  In stock (19 available)
# 19  In stock (19 available)
#
# [20 rows x 2853 columns]

# %%
len(title)
len(price)
len(rating)
len(descriptions)
len(availability)
# Out:
# 980

# %%
# Create a DataFrame
data = {
    "Title": title,
    "Price": price,
    "Rating": rating,
    "Description": descriptions,
    "Availability": availability
}

df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                                    Title    Price Rating  \
# 0                   A Light in the Attic  Â£51.77  Three
# 1                     Tipping the Velvet  Â£53.74    One
# 2                             Soumission  Â£50.10    One
# 3                          Sharp Objects  Â£47.82   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23   Five
#
#                                          Description             Availability
# 0  \n    It's hard to imagine a world without A L...  In stock (19 available)
# 1  \n    "Erotic and absorbing...Written with sta...  In stock (19 available)
# 2  \n    Dans une France assez proche de la nÃ´tr...  In stock (19 available)
# 3  \n    WICKED above her hipbone, GIRL across he...  In stock (19 available)
# 4  \n    From a renowned historian comes a ground...  In stock (19 available)

# %% [markdown]
# **Task 3**: Save all the scrapped data from Task 1 into a CSV file.
#
# <span style="color:red">(1 mark)</span>

# %%
# Save the DataFrame to a CSV file
df.to_csv("books_data_final.csv", index=False)

print("Data saved to books_data.csv!")
# Out:
# Data saved to books_data.csv!
